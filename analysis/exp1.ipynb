# %%
import pandas as pd
from IPython.display import display



# Load the CSV file (update the path if necessary)
#file_path = "../logs/expWed_Mar_12_205415_UTC_2025.csv"  # Ensure the correct filename

# Read the CSV file (using ";" as the delimiter)
df = pd.read_csv("../logs/expWed_Mar_12_205415_UTC_2025.csv", delimiter=";")

# Display the table
df.head()  # Shows the first 5 rows

display(df.head(100))
# Out:
#         time datacenter_id  datacenter_name host_id   type  active  \
# 300.04     2  Datacenter_1                0    host   True       4
# 600.04     2  Datacenter_1                0    host  False       4
# 300.04     2  Datacenter_1                1    host   True       4
# 600.04     2  Datacenter_1                1    host  False       4
# 300.04     2  Datacenter_1                2    host   True       4
# ...      ...           ...              ...     ...    ...     ...
# 600.04     2  Datacenter_1                7    host  False       4
# 300.04     2  Datacenter_1                8    host   True       4
# 600.04     2  Datacenter_1                8    host  False       4
# 300.04     2  Datacenter_1                9    host   True       4
# 600.04     2  Datacenter_1                9    host  False       4
#
#         number_of_pes  available_pes          mips  \
# 300.04              0        10400.0     88.777551
# 600.04              4        10400.0  10400.000000
# ...
